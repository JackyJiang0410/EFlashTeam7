# %% [markdown]
# # Multi-touch Force Exploration
#
# This notebook provides quick exploratory analysis utilities for inspecting the force (`fz`) distribution across all CSV files in a directory.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_rows", 50)
pd.set_option("display.max_columns", 30)

# Set style for better-looking plots
try:
    plt.style.use('seaborn-v0_8-darkgrid')
except OSError:
    try:
        plt.style.use('seaborn-darkgrid')
    except OSError:
        plt.style.use('default')
sns.set_palette("husl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 7
#       5 import pandas as pd
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#       9 pd.set_option("display.max_rows", 50)
#      10 pd.set_option("display.max_columns", 30)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
def summarize_fz(directory: str, threshold: float = 1.0, pattern: str = "*.csv") -> pd.DataFrame:
    """Summarize how many rows fall below the absolute `fz` threshold for every CSV in `directory`.

    Parameters
    ----------
    directory: str
        Path to the folder containing CSV files.
    threshold: float
        Absolute-value cutoff applied to `fz`.
    pattern: str
        Glob pattern for CSV selection (default: '*.csv').
    """
    base_path = Path(directory)
    if not base_path.exists():
        raise FileNotFoundError(f"Directory not found: {directory}")

    rows = []
    for csv_path in sorted(base_path.glob(pattern)):
        try:
            df = pd.read_csv(csv_path)
        except Exception as exc:
            rows.append({
                "file": csv_path.name,
                "total_rows": np.nan,
                "valid_fz_rows": np.nan,
                "abs_fz_lt_threshold": np.nan,
                "abs_fz_ge_threshold": np.nan,
                "note": f"Failed to read: {exc}"
            })
            continue

        if "fz" not in df.columns:
            rows.append({
                "file": csv_path.name,
                "total_rows": len(df),
                "valid_fz_rows": 0,
                "abs_fz_lt_threshold": np.nan,
                "abs_fz_ge_threshold": np.nan,
                "note": "Missing 'fz' column"
            })
            continue

        fz = pd.to_numeric(df["fz"], errors="coerce")
        valid_mask = ~fz.isna()
        valid_count = valid_mask.sum()
        abs_fz = fz[valid_mask].abs()

        below = (abs_fz < threshold).sum()
        above = (abs_fz >= threshold).sum()

        rows.append({
            "file": csv_path.name,
            "total_rows": len(df),
            "valid_fz_rows": valid_count,
            "abs_fz_lt_threshold": below,
            "abs_fz_ge_threshold": above,
            "pct_fz_lt_threshold": below / valid_count * 100 if valid_count else np.nan,
            "note": ""
        })

    summary = pd.DataFrame(rows)
    if not summary.empty:
        summary = summary.sort_values("file").reset_index(drop=True)
    return summary

# %%
multi_touch_dir = "../Database/Data/single_touch_data"
summary = summarize_fz(multi_touch_dir, threshold=1.0, pattern="*.csv")
summary
# Out:
#                              file  total_rows  valid_fz_rows  \
# 0  position_1_20251120_191302.csv        1289           1289
# 1  position_2_20251120_193255.csv        1722           1722
# 2  position_3_20251120_190653.csv        1216           1216
# 3  position_4_20251120_192527.csv        1408           1408
# 4  position_5_20251120_190015.csv        1150           1150
# 5  position_6_20251120_191906.csv        1071           1071
# 6  position_7_20251120_181517.csv        2165           2165
# 7  position_8_20251120_193831.csv        1112           1112
# 8  position_9_20251120_184740.csv        1787           1787
#
#    abs_fz_lt_threshold  abs_fz_ge_threshold  pct_fz_lt_threshold note
# 0                  456                  833            35.376261
# 1                 1162                  560            67.479675
# 2                  472                  744            38.815789
# 3                  639                  769            45.383523
# ...

# %%
totals = summary[["valid_fz_rows", "abs_fz_lt_threshold", "abs_fz_ge_threshold"]].sum()
shares = {
    "pct_lt_threshold": totals["abs_fz_lt_threshold"] / totals["valid_fz_rows"] * 100 if totals["valid_fz_rows"] else np.nan,
    "pct_ge_threshold": totals["abs_fz_ge_threshold"] / totals["valid_fz_rows"] * 100 if totals["valid_fz_rows"] else np.nan,
}

totals.to_frame(name="count"), shares
# Out:
# (                     count
#  valid_fz_rows        12920
#  abs_fz_lt_threshold   6214
#  abs_fz_ge_threshold   6706,
#  {'pct_lt_threshold': np.float64(48.09597523219814),
#   'pct_ge_threshold': np.float64(51.90402476780186)})

# %%
def visualize_fz_distribution(directory: str, pattern: str = "*.csv", threshold: float = 1.0):
    """Visualize the distribution of absolute fz values from all CSV files in a directory.
    
    Parameters
    ----------
    directory: str
        Path to the folder containing CSV files.
    pattern: str
        Glob pattern for CSV selection (default: '*.csv').
    threshold: float
        Threshold value to highlight in visualizations (default: 1.0 N).
    """
    base_path = Path(directory)
    if not base_path.exists():
        raise FileNotFoundError(f"Directory not found: {directory}")
    
    all_fz = []
    file_labels = []
    
    for csv_path in sorted(base_path.glob(pattern)):
        try:
            df = pd.read_csv(csv_path)
            if "fz" not in df.columns:
                continue
            
            fz = pd.to_numeric(df["fz"], errors="coerce")
            valid_fz = fz.dropna()
            abs_fz = valid_fz.abs()
            
            all_fz.extend(abs_fz.tolist())
            file_labels.extend([csv_path.name] * len(abs_fz))
        except Exception as exc:
            print(f"Warning: Failed to read {csv_path.name}: {exc}")
            continue
    
    if not all_fz:
        print("No valid fz data found in the directory.")
        return
    
    fz_array = np.array(all_fz)
    
    # Create figure with subplots
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle(f'Force (fz) Distribution Analysis\nDirectory: {directory}', fontsize=16, fontweight='bold')
    
    # 1. Histogram
    ax1 = axes[0, 0]
    ax1.hist(fz_array, bins=50, edgecolor='black', alpha=0.7)
    ax1.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold} N')
    ax1.axvline(fz_array.mean(), color='green', linestyle='--', linewidth=2, label=f'Mean: {fz_array.mean():.3f} N')
    ax1.axvline(np.median(fz_array), color='blue', linestyle='--', linewidth=2, label=f'Median: {np.median(fz_array):.3f} N')
    ax1.set_xlabel('Absolute Force |fz| (N)', fontsize=12)
    ax1.set_ylabel('Frequency', fontsize=12)
    ax1.set_title('Histogram of |fz| Distribution', fontsize=14, fontweight='bold')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 2. Box plot
    ax2 = axes[0, 1]
    box_data = [fz_array]
    bp = ax2.boxplot(box_data, vert=True, patch_artist=True, labels=['|fz|'])
    bp['boxes'][0].set_facecolor('lightblue')
    ax2.axhline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold} N')
    ax2.set_ylabel('Absolute Force |fz| (N)', fontsize=12)
    ax2.set_title('Box Plot of |fz| Distribution', fontsize=14, fontweight='bold')
    ax2.legend()
    ax2.grid(True, alpha=0.3, axis='y')
    
    # 3. Cumulative Distribution Function (CDF)
    ax3 = axes[1, 0]
    sorted_fz = np.sort(fz_array)
    cumulative = np.arange(1, len(sorted_fz) + 1) / len(sorted_fz)
    ax3.plot(sorted_fz, cumulative * 100, linewidth=2)
    ax3.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: {threshold} N')
    ax3.axhline(50, color='gray', linestyle=':', linewidth=1, alpha=0.5)
    ax3.set_xlabel('Absolute Force |fz| (N)', fontsize=12)
    ax3.set_ylabel('Cumulative Percentage (%)', fontsize=12)
    ax3.set_title('Cumulative Distribution Function (CDF)', fontsize=14, fontweight='bold')
    ax3.legend()
    ax3.grid(True, alpha=0.3)
    
    # 4. Statistics summary text
    ax4 = axes[1, 1]
    ax4.axis('off')
    
    stats_text = f"""
    Statistics Summary:
    
    Total Samples: {len(fz_array):,}
    
    Mean: {fz_array.mean():.3f} N
    Median: {np.median(fz_array):.3f} N
    Std Dev: {fz_array.std():.3f} N
    
    Min: {fz_array.min():.3f} N
    Max: {fz_array.max():.3f} N
    
    25th Percentile: {np.percentile(fz_array, 25):.3f} N
    75th Percentile: {np.percentile(fz_array, 75):.3f} N
    
    Samples < {threshold} N: {(fz_array < threshold).sum():,} ({(fz_array < threshold).sum() / len(fz_array) * 100:.1f}%)
    Samples >= {threshold} N: {(fz_array >= threshold).sum():,} ({(fz_array >= threshold).sum() / len(fz_array) * 100:.1f}%)
    """
    
    ax4.text(0.1, 0.5, stats_text, fontsize=11, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.tight_layout()
    plt.show()
    
    return fz_array

# %%
# Example usage: Visualize fz distribution for single_touch_data
single_touch_dir = "../Database/Data/single_touch_data"
fz_data = visualize_fz_distribution(single_touch_dir, pattern="position_*.csv", threshold=1.0)
# Out:
# /tmp/ipykernel_810140/2494478737.py:61: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax2.boxplot(box_data, vert=True, patch_artist=True, labels=['|fz|'])

# %%
# Example usage: Visualize fz distribution for multi_touch_data
multi_touch_dir = "../Database/Data/multi_touch_data"
fz_data_multi = visualize_fz_distribution(multi_touch_dir, pattern="multi_touch_*.csv", threshold=1.0)

# %%
def visualize_fz_original_distribution(directory: str, pattern: str = "*.csv", threshold: float = 1.0):
    """Visualize the distribution of original fz values (with sign) from all CSV files in a directory.
    
    Parameters
    ----------
    directory: str
        Path to the folder containing CSV files.
    pattern: str
        Glob pattern for CSV selection (default: '*.csv').
    threshold: float
        Threshold value to highlight in visualizations (default: 1.0 N).
    """
    base_path = Path(directory)
    if not base_path.exists():
        raise FileNotFoundError(f"Directory not found: {directory}")
    
    all_fz = []
    all_abs_fz = []
    file_labels = []
    
    for csv_path in sorted(base_path.glob(pattern)):
        try:
            df = pd.read_csv(csv_path)
            if "fz" not in df.columns:
                continue
            
            fz = pd.to_numeric(df["fz"], errors="coerce")
            valid_fz = fz.dropna()
            
            all_fz.extend(valid_fz.tolist())
            all_abs_fz.extend(valid_fz.abs().tolist())
            file_labels.extend([csv_path.name] * len(valid_fz))
        except Exception as exc:
            print(f"Warning: Failed to read {csv_path.name}: {exc}")
            continue
    
    if not all_fz:
        print("No valid fz data found in the directory.")
        return
    
    fz_array = np.array(all_fz)
    abs_fz_array = np.array(all_abs_fz)
    
    # Create figure with subplots
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle(f'Original Force (fz) Distribution Analysis (with sign)\nDirectory: {directory}', 
                 fontsize=16, fontweight='bold')
    
    # 1. Histogram of original fz (with sign)
    ax1 = axes[0, 0]
    ax1.hist(fz_array, bins=50, edgecolor='black', alpha=0.7, color='skyblue')
    ax1.axvline(threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: +{threshold} N')
    ax1.axvline(-threshold, color='red', linestyle='--', linewidth=2, label=f'Threshold: -{threshold} N')
    ax1.axvline(fz_array.mean(), color='green', linestyle='--', linewidth=2, label=f'Mean: {fz_array.mean():.3f} N')
    ax1.axvline(np.median(fz_array), color='blue', linestyle='--', linewidth=2, label=f'Median: {np.median(fz_array):.3f} N')
    ax1.axvline(0, color='black', linestyle='-', linewidth=1, alpha=0.5)
    ax1.set_xlabel('Force fz (N)', fontsize=12)
    ax1.set_ylabel('Frequency', fontsize=12)
    ax1.set_title('Histogram of Original fz Distribution (with sign)', fontsize=14, fontweight='bold')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 2. Comparison: Positive vs Negative fz
    ax2 = axes[0, 1]
    positive_count = (fz_array > 0).sum()
    negative_count = (fz_array < 0).sum()
    zero_count = (fz_array == 0).sum()
    
    categories = ['Positive\n(fz > 0)', 'Negative\n(fz < 0)', 'Zero\n(fz = 0)']
    counts = [positive_count, negative_count, zero_count]
    colors = ['green', 'red', 'gray']
    
    bars = ax2.bar(categories, counts, color=colors, alpha=0.7, edgecolor='black')
    ax2.set_ylabel('Count', fontsize=12)
    ax2.set_title('Distribution of fz Signs', fontsize=14, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    
    # Add count labels on bars
    for bar, count in zip(bars, counts):
        height = bar.get_height()
        ax2.text(bar.get_x() + bar.get_width()/2., height,
                f'{count:,}\n({count/len(fz_array)*100:.1f}%)',
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    # 3. Violin plot showing distribution by sign
    ax3 = axes[1, 0]
    positive_fz = fz_array[fz_array > 0]
    negative_fz = fz_array[fz_array < 0]
    
    data_to_plot = []
    labels_to_plot = []
    if len(positive_fz) > 0:
        data_to_plot.append(positive_fz)
        labels_to_plot.append(f'Positive\n(n={len(positive_fz)})')
    if len(negative_fz) > 0:
        data_to_plot.append(negative_fz)
        labels_to_plot.append(f'Negative\n(n={len(negative_fz)})')
    
    if data_to_plot:
        parts = ax3.violinplot(data_to_plot, positions=range(len(data_to_plot)), 
                               showmeans=True, showmedians=True)
        ax3.set_xticks(range(len(labels_to_plot)))
        ax3.set_xticklabels(labels_to_plot)
        ax3.axhline(0, color='black', linestyle='-', linewidth=1, alpha=0.3)
        ax3.axhline(threshold, color='red', linestyle='--', linewidth=1, alpha=0.5, label=f'±{threshold} N')
        ax3.axhline(-threshold, color='red', linestyle='--', linewidth=1, alpha=0.5)
        ax3.set_ylabel('Force fz (N)', fontsize=12)
        ax3.set_title('Violin Plot: fz Distribution by Sign', fontsize=14, fontweight='bold')
        ax3.legend()
        ax3.grid(True, alpha=0.3, axis='y')
        
        # Color the violins
        for pc in parts['bodies']:
            pc.set_facecolor('lightblue')
            pc.set_alpha(0.7)
    
    # 4. Statistics summary text
    ax4 = axes[1, 1]
    ax4.axis('off')
    
    positive_pct = (fz_array > 0).sum() / len(fz_array) * 100
    negative_pct = (fz_array < 0).sum() / len(fz_array) * 100
    zero_pct = (fz_array == 0).sum() / len(fz_array) * 100
    
    stats_text = f"""
    Statistics Summary (Original fz):
    
    Total Samples: {len(fz_array):,}
    
    Mean: {fz_array.mean():.3f} N
    Median: {np.median(fz_array):.3f} N
    Std Dev: {fz_array.std():.3f} N
    
    Min: {fz_array.min():.3f} N
    Max: {fz_array.max():.3f} N
    
    25th Percentile: {np.percentile(fz_array, 25):.3f} N
    75th Percentile: {np.percentile(fz_array, 75):.3f} N
    
    Sign Distribution:
    Positive (fz > 0): {positive_count:,} ({positive_pct:.1f}%)
    Negative (fz < 0): {negative_count:,} ({negative_pct:.1f}%)
    Zero (fz = 0): {zero_count:,} ({zero_pct:.1f}%)
    
    Threshold Analysis:
    |fz| < {threshold} N: {(abs_fz_array < threshold).sum():,} ({(abs_fz_array < threshold).sum() / len(fz_array) * 100:.1f}%)
    |fz| >= {threshold} N: {(abs_fz_array >= threshold).sum():,} ({(abs_fz_array >= threshold).sum() / len(fz_array) * 100:.1f}%)
    """
    
    ax4.text(0.1, 0.5, stats_text, fontsize=10, family='monospace',
             verticalalignment='center', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.tight_layout()
    plt.show()
    
    return fz_array

# %%
# Example usage: Visualize original fz distribution (with sign) for single_touch_data
single_touch_dir = "../Database/Data/single_touch_data"
fz_original_data = visualize_fz_original_distribution(single_touch_dir, pattern="position_*.csv", threshold=1.0)

# %%
# Example usage: Visualize original fz distribution (with sign) for multi_touch_data
multi_touch_dir = "../Database/Data/multi_touch_data"
fz_original_multi = visualize_fz_original_distribution(multi_touch_dir, pattern="multi_touch_*.csv", threshold=1.0)
